# %%
#  Ebnable HTML/CSS 
from IPython.core.display import HTML
HTML("<link href='https://fonts.googleapis.com/css?family=Passion+One' rel='stylesheet' type='text/css'><style>div.attn { font-family: 'Helvetica Neue'; font-size: 30px; line-height: 40px; color: #FFFFFF; text-align: center; margin: 30px 0; border-width: 10px 0; border-style: solid; border-color: #5AAAAA; padding: 30px 0; background-color: #DDDDFF; }hr { border: 0; background-color: #ffffff; border-top: 1px solid black; }hr.major { border-top: 10px solid #5AAA5A; }hr.minor { border: none; background-color: #ffffff; border-top: 5px dotted #CC3333; }div.bubble { width: 65%; padding: 20px; background: #DDDDDD; border-radius: 15px; margin: 0 auto; font-style: italic; color: #f00; }em { color: #AAA; }div.c1{visibility:hidden;margin:0;height:0;}div.note{color:red;}</style>")
# Out:
# <link href='https://fonts.googleapis.com/css?family=Passion+One' rel='stylesheet' type='text/css'><style>div.attn { font-family: 'Helvetica Neue'; font-size: 30px; line-height: 40px; color: #FFFFFF; text-align: center; margin: 30px 0; border-width: 10px 0; border-style: solid; border-color: #5AAAAA; padding: 30px 0; background-color: #DDDDFF; }hr { border: 0; background-color: #ffffff; border-top: 1px solid black; }hr.major { border-top: 10px solid #5AAA5A; }hr.minor { border: none; background-color: #ffffff; border-top: 5px dotted #CC3333; }div.bubble { width: 65%; padding: 20px; background: #DDDDDD; border-radius: 15px; margin: 0 auto; font-style: italic; color: #f00; }em { color: #AAA; }div.c1{visibility:hidden;margin:0;height:0;}div.note{color:red;}</style>

# %% [markdown]
# ___
# Enter Team Member Names here (double click to edit):
#
# - Name 1: Ryan Bass
# - Name 2: Brett Benefield
# - Name 3: Cho Kim
# - Name 4: Nicole Wittlin

# %% [markdown]
# ________
#
# # In Class Assignment Five
# In the following assignment you will be asked to fill in python code and derivations for a number of different problems. Please read all instructions carefully and turn in the rendered notebook (or HTML of the rendered notebook) before the end of class. Be sure to save the notebook before uploading.
#
# <a id="top"></a>
# ## Contents
# * <a href="#testing">Testing R Magics</a>
# * <a href="#understand">Understanding the Data Representation</a>
# * <a href="#apriori">Finding Frequent Items</a>
# * <a href="#candidates">Generating Candidates</a>
# * <a href="#arules">Using ARules and ARulesViz</a>
#
# ________________________________________________________________________________________________________
#
# <a id="testing"></a>
# <a href="#top">Back to Top</a>
#
# ## Running in the 'R' Ecosystem with magics
# If you did not get Rpy2, R, or the dependencies arules and arulesViz installed on your system, then you will need to skip this part and go on to the first question. You will need to run the appropriate block of code in this notebook depending on if you have Rpy2 running or not. Each block is marked appropriately, so read the block before running it.

# %%
# getting things started
import time
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
# %matplotlib inline

# %%
#==========================
#IF USING R, RUN THIS CODE
#==========================
# You will need to have R installed, as well as Rpy2 and the arules library
from rpy2.robjects.packages import importr
from rpy2 import robjects as robj

# this way we can write r code by simply writing %R
# %load_ext rmagic
# %load_ext rpy2.ipython 
# this enables the %R extension to iPython (does not work outside of the iPython shell)

# these packages will need to be installed
# open R and run 
#     install.package(arules)
#     install.package(arulesViz)

arules = importr('arules') # same as importing in R with the "library" command
arules_viz = importr('arulesViz') # visualize the different rules
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-3-f8164e395c36> in <module>
#       3 #==========================
#       4 # You will need to have R installed, as well as Rpy2 and the arules library
# ----> 5 from rpy2.robjects.packages import importr
#       6 from rpy2 import robjects as robj
#       7
#
# ModuleNotFoundError: No module named 'rpy2'

# %% [markdown]
# If you receive a warning on the above block, try to run it again and verify that everything is loaded properly.
# ___

# %%
#==========================
#IF USING R, RUN THIS CODE
#==========================

# %R load("titanic2.raw.rdata")
# %R rules <- apriori(titanic.raw,parameter = list(minlen=2, supp=0.05, conf=0.8))
# %R rules.sorted <- sort(rules, by="lift")
# %R plot(rules.sorted, method="grouped")

print('Arules run now from R, test complete')
# Out:
# Parameter specification:
#  confidence minval smax arem  aval originalSupport support minlen maxlen target
#         0.8    0.1    1 none FALSE            TRUE    0.05      2     10  rules
#    ext
#  FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# apriori - find association rules with the apriori algorithm
# version 4.21 (2004.05.09)        (c) 1996-2004   Christian Borgelt
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[10 item(s), 2201 transaction(s)] done [0.00s].
# sorting and recoding items ... [9 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 4 done [0.00s].
# writing ... [49 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# Arules run now from R, test complete

# %% [markdown]
# ___
# <a id="understand"></a>
# <a href="#top">Back to Top</a>
# ## Understanding the dataset
# We have used the titanic dataset before in class, however this dataset has been pruned to only include the social class, sex, age (as a nominal), and if the individual survived. The data can be stored in many ways, but is stored here as a table of values.
#
# **Question**: Is this dataset a typical example of *transaction* data (*i.e.*, like the grocery store transaction data)? Why or Why not? What makes it similar or different? **Hint**: think about the possible itemset lattice and how it might be different/similar. What makes an item in this dataset?

# %% [markdown]
# ___
# Enter your answer here:
#
# No. This data has a constant nmber of items in each transaction. This differs from a typical example (ex. grocery store transaction data) because transaction size varies widely and can have multiples of certain items in a transaction. This data set is not a multi-dimensional reality, therefore a person cannot be both genders or be a crew member and not at the same time. Unlike a grocery store transaction that might have both milk and orange juice.
#
#
#
# ___

# %% [markdown]
# <a id="apriori"></a>
# <a href="#top">Back to Top</a>
# ## Frequent Itemsets and Apriori
# Run the following line of code to grab the R loaded data.frame and save it into a pandas dataframe.
#
# Please run the appropriate block of code for whether you have Ry2 installed or not!

# %%
#==========================
#IF USING R, RUN THIS CODE
#==========================
# Use rmagics to save the dataframe into pandas
#(R output)(python var) ( this is all R code)
# %R -o df_from_R df_from_R <- titanic.raw

# now we have the exact same dataset as the one from R
# but it is now a pandas dataframe
print(df_from_R.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2201 entries, 1 to 2201
# Data columns (total 4 columns):
# Class       2201 non-null object
# Sex         2201 non-null object
# Age         2201 non-null object
# Survived    2201 non-null object
# dtypes: object(4)
# memory usage: 86.0+ KB
# None

# %%
#===============================
# IF NOT USING R RUN THIS CODE
#===============================
# getting things started
import time
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
# %matplotlib inline

df_from_R = pd.read_csv('Rframe_as_pandas.csv')
df_from_R.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2201 entries, 0 to 2200
# Data columns (total 5 columns):
# Unnamed: 0    2201 non-null int64
# Class         2201 non-null object
# Sex           2201 non-null object
# Age           2201 non-null object
# Survived      2201 non-null object
# dtypes: int64(1), object(4)
# memory usage: 86.1+ KB

# %%
#==========================================
# RUN THIS CODE NO MATTER IF USING R OR NOT
#==========================================
plt.style.use('ggplot')

# Now lets plot the number of times each itemset occurs graphically
# find counts of the four itemsets
f = plt.figure(figsize=(10,5))
df_grouped = df_from_R.groupby(by=['Class','Age','Sex'])
ax = df_grouped.Survived.value_counts().plot(kind='barh')
plt.title('Support count for all 4-itemsets')

# find all the three itemsets and concat them
f = plt.figure(figsize=(10,7))
df_grouped = df_from_R.groupby(by=['Class','Age'])
countsA = df_grouped.Survived.value_counts()
df_grouped = df_from_R.groupby(by=['Class','Sex'])
countsB = df_grouped.Survived.value_counts()
df_grouped = df_from_R.groupby(by=['Age','Sex'])
countsC = df_grouped.Survived.value_counts()

pd.concat((countsA,countsB,countsC)).plot(kind='barh')
plt.title('Support count for some 3-itemsets')
# Out:
# Text(0.5, 1.0, 'Support count for some 3-itemsets')

# %% [markdown]
# Use the graphs above to estimate the values for the following quantities. You do not need to calculate counts from the dataset, just try to get close by viewing from the graph. Recall that for a given rule, $X\rightarrow Y$, the confidence is given by
# $$c=\frac{\sigma( X \cup Y)}{\sigma( X )} $$
#
# **Questions**: Given the graphs above, what is the support count, $\sigma$, and support, $s$, for the itemset {1st, Adult, Yes}? What about the itemset {1st, Adult, Yes, Female}?
#
# **Question**: What is the confidence, $c$, for the rule {1st, Adult, Yes} $\rightarrow$ {Female}?

# %% [markdown]
# ___
# Enter your answer here:
#
# The support count for {1, adult, yes} is s ≈ 197, σ = 0.0895
#
# The support count for {1, adult, yes, female} is s ≈ 140, σ = 0.0636
#
# confidence is about 71%

# %%
# Insert any calculations needed to answer the above question here

# Insert any calculations needed to answer the above question here
cnts = df_from_R.groupby(by=['Class','Age','Sex','Survived']).count()
print(cnts.iloc[1])
num_XUY = cnts.iloc[1].values

cnts = df_from_R.groupby(by=['Class','Age','Survived']).count()
print(cnts.iloc[1])
num_X = cnts.iloc[1].values

print(float(num_XUY) / num_X)
# Out:
# Unnamed: 0    140
# Name: (1st, Adult, Female, Yes), dtype: int64
# Unnamed: 0    197
# Sex           197
# Name: (1st, Adult, Yes), dtype: int64
# [0.7106599 0.7106599]

# %% [markdown]
# ___
# **Question**: What is the support count (an integer) for a *minsup* threshold of 0.25? Using the support count graphs above, which itemsets would be considered frequent with a *minsup* of 0.25? Are any of the 4-itemsets also maximal for this value of *minsup*? Why or Why not?

# %% [markdown]
# ___
# Enter your answer here:
#
# Minsup = 550.25
#
# 4-itemset graph: {Crew, Adult, Male, No}
#
# 3-itemset graph: {Adult, Male, No}, {Crew, Male, No}, {Crew, Adult, No}
#
# Yes. {Crew, Adult, Male, No} is maximal because none of its supersets are infrequent.

# %%
# Insert any calculations needed to answer the above question here
2201*0.25
# Out:
# 550.25

# %% [markdown]
# ___
# # Start of Live Session Assignment
# <a id="candidates"></a>
# <a href="#top">Back to Top</a>
# ### Generating candidates
# Assume that the 3-itemset bar graph above contains ALL the possible frequent 3-itemsets in the titanic dataset and their support count.
#
# **Exercise**: If the minimum support count equals 200, then use the bar graph to select the 3-itemsets that are frequent. Use these itemsets and the apriori principle to generate candidate 4-itemsets that might be frequent. Please show your thought process.

# %% [markdown]
# ___
# Enter your answer here:
#
# frequent 3-itemsets:
# {Adult, Male, Yes}
# {Adult, Male, No}
# {Adult, Female, Yes}
# {Crew, Male, No}
# {3rd, Male, No}
# {Crew, Adult, Yes}
# {Crew, Adult, No}
# {3rd, Adult, No}
#
# frequent 4-itemsets:
# {Crew, Adult, Male, No}
# {3rd, Adult, Male, No}
#
# The though process used was to idenitfy all itemsets who's support count was greater than or equal to 200 on the support count bar graph above.

# %% [markdown]
# ___
# <a id="arules"></a>
# <a href="#top">Back to Top</a>
# ## Using the Arules Package to Interpret Data
# Run the following R code to run the Apriori algorithm on the titanic dataset.
#
# **Exercise**: Change the parameters of the apriori algorithm in order to check your results from the previous question. That is, change the minlen, supp, and conf parameters so that it only displays 4-itemsets with minimum "support count" of 200. Do the itemsets from the resulting rules match with what you found in the previous questions? Should they? Why or why not?

# %%
#==========================
# IF USING R RUN THIS CODE
#==========================
# %R load("titanic2.raw.rdata")
# %R rules <- apriori(titanic.raw,parameter = list(minlen=1, supp=0.01, conf=0.01))
# %R rules.sorted <- sort(rules, by="support")
# %R inspect(rules.sorted)
# Out:
# Parameter specification:
#  confidence minval smax arem  aval originalSupport support minlen maxlen target
#        0.01    0.1    1 none FALSE            TRUE    0.01      1     10  rules
#    ext
#  FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# apriori - find association rules with the apriori algorithm
# version 4.21 (2004.05.09)        (c) 1996-2004   Christian Borgelt
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[10 item(s), 2201 transaction(s)] done [0.00s].
# sorting and recoding items ... [10 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 4 done [0.00s].
# writing ... [246 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
#     lhs               rhs               support confidence      lift
# 1   {}             => {Age=Adult}    0.95047706 0.95047706 1.0000000
# 2   {}             => {Sex=Male}     0.78646070 0.78646070 1.0000000
# 3   {Sex=Male}     => {Age=Adult}    0.75738301 0.96302715 1.0132040
# 4   {Age=Adult}    => {Sex=Male}     0.75738301 0.79684512 1.0132040
# 5   {}             => {Survived=No}  0.67696502 0.67696502 1.0000000
# 6   {Survived=No}  => {Age=Adult}    0.65333939 0.96510067 1.0153856
# 7   {Age=Adult}    => {Survived=No}  0.65333939 0.68738050 1.0153856
# 8   {Survived=No}  => {Sex=Male}     0.61971831 0.91543624 1.1639949
# 9   {Sex=Male}     => {Survived=No}  0.61971831 0.78798382 1.1639949
# 10  {Sex=Male,
#      Survived=No}  => {Age=Adult}    0.60381645 0.97434018 1.0251065
# 11  {Age=Adult,
#      Survived=No}  => {Sex=Male}     0.60381645 0.92420028 1.1751385
# 12  {Sex=Male,
#      Age=Adult}    => {Survived=No}  0.60381645 0.79724055 1.1776688
# 13  {}             => {Class=Crew}   0.40208996 0.40208996 1.0000000
# 14  {Class=Crew}   => {Age=Adult}    0.40208996 1.00000000 1.0521033
# 15  {Age=Adult}    => {Class=Crew}   0.40208996 0.42304015 1.0521033
# 16  {Class=Crew}   => {Sex=Male}     0.39164016 0.97401130 1.2384742
# 17  {Sex=Male}     => {Class=Crew}   0.39164016 0.49797805 1.2384742
# 18  {Class=Crew,
#      Sex=Male}     => {Age=Adult}    0.39164016 1.00000000 1.0521033
# 19  {Class=Crew,
#      Age=Adult}    => {Sex=Male}     0.39164016 0.97401130 1.2384742
# 20  {Sex=Male,
#      Age=Adult}    => {Class=Crew}   0.39164016 0.51709658 1.2860221
# 21  {}             => {Survived=Yes} 0.32303498 0.32303498 1.0000000
# 22  {}             => {Class=3rd}    0.32076329 0.32076329 1.0000000
# 23  {Class=Crew}   => {Survived=No}  0.30577010 0.76045198 1.1233254
# 24  {Survived=No}  => {Class=Crew}   0.30577010 0.45167785 1.1233254
# 25  {Class=Crew,
#      Survived=No}  => {Age=Adult}    0.30577010 1.00000000 1.0521033
# 26  {Class=Crew,
#      Age=Adult}    => {Survived=No}  0.30577010 0.76045198 1.1233254
# 27  {Age=Adult,
#      Survived=No}  => {Class=Crew}   0.30577010 0.46801113 1.1639463
# 28  {Class=Crew,
#      Survived=No}  => {Sex=Male}     0.30440709 0.99554235 1.2658514
# 29  {Class=Crew,
#      Sex=Male}     => {Survived=No}  0.30440709 0.77726218 1.1481571
# 30  {Sex=Male,
#      Survived=No}  => {Class=Crew}   0.30440709 0.49120235 1.2216230
# 31  {Class=Crew,
#      Sex=Male,
#      Survived=No}  => {Age=Adult}    0.30440709 1.00000000 1.0521033
# 32  {Class=Crew,
#      Age=Adult,
#      Survived=No}  => {Sex=Male}     0.30440709 0.99554235 1.2658514
# 33  {Class=Crew,
#      Sex=Male,
#      Age=Adult}    => {Survived=No}  0.30440709 0.77726218 1.1481571
# 34  {Sex=Male,
#      Age=Adult,
#      Survived=No}  => {Class=Crew}   0.30440709 0.50413845 1.2537952
# 35  {Survived=Yes} => {Age=Adult}    0.29713766 0.91983122 0.9677574
# 36  {Age=Adult}    => {Survived=Yes} 0.29713766 0.31261950 0.9677574
# 37  {Class=3rd}    => {Age=Adult}    0.28487051 0.88810198 0.9343750
# 38  {Age=Adult}    => {Class=3rd}    0.28487051 0.29971319 0.9343750
# 39  {Class=3rd}    => {Survived=No}  0.23989096 0.74787535 1.1047474
# 40  {Survived=No}  => {Class=3rd}    0.23989096 0.35436242 1.1047474
# 41  {Class=3rd}    => {Sex=Male}     0.23171286 0.72237960 0.9185196
# 42  {Sex=Male}     => {Class=3rd}    0.23171286 0.29462738 0.9185196
# 43  {Class=3rd,
#      Survived=No}  => {Age=Adult}    0.21626533 0.90151515 0.9484870
# 44  {Class=3rd,
#      Age=Adult}    => {Survived=No}  0.21626533 0.75917065 1.1214326
# 45  {Age=Adult,
#      Survived=No}  => {Class=3rd}    0.21626533 0.33101530 1.0319613
# 46  {}             => {Sex=Female}   0.21353930 0.21353930 1.0000000
# 47  {Class=3rd,
#      Sex=Male}     => {Age=Adult}    0.20990459 0.90588235 0.9530818
# 48  {Class=3rd,
#      Age=Adult}    => {Sex=Male}     0.20990459 0.73684211 0.9369090
# 49  {Sex=Male,
#      Age=Adult}    => {Class=3rd}    0.20990459 0.27714457 0.8640159
# 50  {Sex=Female}   => {Age=Adult}    0.19309405 0.90425532 0.9513700
# 51  {Age=Adult}    => {Sex=Female}   0.19309405 0.20315488 0.9513700
# 52  {Class=3rd,
#      Survived=No}  => {Sex=Male}     0.19173103 0.79924242 1.0162522
# 53  {Class=3rd,
#      Sex=Male}     => {Survived=No}  0.19173103 0.82745098 1.2222950
# 54  {Sex=Male,
#      Survived=No}  => {Class=3rd}    0.19173103 0.30938416 0.9645249
# 55  {Class=3rd,
#      Sex=Male,
#      Survived=No}  => {Age=Adult}    0.17582917 0.91706161 0.9648435
# 56  {Class=3rd,
#      Age=Adult,
#      Survived=No}  => {Sex=Male}     0.17582917 0.81302521 1.0337773
# 57  {Class=3rd,
#      Sex=Male,
#      Age=Adult}    => {Survived=No}  0.17582917 0.83766234 1.2373791
# 58  {Sex=Male,
#      Age=Adult,
#      Survived=No}  => {Class=3rd}    0.17582917 0.29119639 0.9078233
# 59  {Survived=Yes} => {Sex=Male}     0.16674239 0.51617440 0.6563257
# 60  {Sex=Male}     => {Survived=Yes} 0.16674239 0.21201618 0.6563257
# 61  {Sex=Female}   => {Survived=Yes} 0.15629259 0.73191489 2.2657450
# 62  {Survived=Yes} => {Sex=Female}   0.15629259 0.48382560 2.2657450
# 63  {Sex=Male,
#      Survived=Yes} => {Age=Adult}    0.15356656 0.92098093 0.9689670
# 64  {Age=Adult,
#      Survived=Yes} => {Sex=Male}     0.15356656 0.51681957 0.6571461
# 65  {Sex=Male,
#      Age=Adult}    => {Survived=Yes} 0.15356656 0.20275945 0.6276702
# 66  {}             => {Class=1st}    0.14766015 0.14766015 1.0000000
# 67  {Class=1st}    => {Age=Adult}    0.14493412 0.98153846 1.0326798
# 68  {Age=Adult}    => {Class=1st}    0.14493412 0.15248566 1.0326798
# 69  {Sex=Female,
#      Survived=Yes} => {Age=Adult}    0.14357110 0.91860465 0.9664669
# 70  {Sex=Female,
#      Age=Adult}    => {Survived=Yes} 0.14357110 0.74352941 2.3016993
# 71  {Age=Adult,
#      Survived=Yes} => {Sex=Female}   0.14357110 0.48318043 2.2627237
# 72  {}             => {Class=2nd}    0.12948660 0.12948660 1.0000000
# 73  {Class=2nd}    => {Age=Adult}    0.11858246 0.91578947 0.9635051
# 74  {Age=Adult}    => {Class=2nd}    0.11858246 0.12476099 0.9635051
# 75  {Survived=Yes} => {Class=Crew}   0.09631985 0.29817159 0.7415544
# 76  {Class=Crew}   => {Survived=Yes} 0.09631985 0.23954802 0.7415544
# 77  {Class=Crew,
#      Survived=Yes} => {Age=Adult}    0.09631985 1.00000000 1.0521033
# 78  {Age=Adult,
#      Survived=Yes} => {Class=Crew}   0.09631985 0.32415902 0.8061853
# 79  {Class=Crew,
#      Age=Adult}    => {Survived=Yes} 0.09631985 0.23954802 0.7415544
# 80  {Class=1st}    => {Survived=Yes} 0.09223080 0.62461538 1.9335843
# 81  {Survived=Yes} => {Class=1st}    0.09223080 0.28551336 1.9335843
# 82  {Class=1st,
#      Survived=Yes} => {Age=Adult}    0.08950477 0.97044335 1.0210066
# 83  {Class=1st,
#      Age=Adult}    => {Survived=Yes} 0.08950477 0.61755486 1.9117275
# 84  {Age=Adult,
#      Survived=Yes} => {Class=1st}    0.08950477 0.30122324 2.0399765
# 85  {Sex=Female}   => {Class=3rd}    0.08905043 0.41702128 1.3000904
# 86  {Class=3rd}    => {Sex=Female}   0.08905043 0.27762040 1.3000904
# 87  {Class=Crew,
#      Survived=Yes} => {Sex=Male}     0.08723308 0.90566038 1.1515647
# 88  {Sex=Male,
#      Survived=Yes} => {Class=Crew}   0.08723308 0.52316076 1.3011038
# 89  {Class=Crew,
#      Sex=Male}     => {Survived=Yes} 0.08723308 0.22273782 0.6895161
# 90  {Class=Crew,
#      Sex=Male,
#      Survived=Yes} => {Age=Adult}    0.08723308 1.00000000 1.0521033
# 91  {Class=Crew,
#      Age=Adult,
#      Survived=Yes} => {Sex=Male}     0.08723308 0.90566038 1.1515647
# 92  {Sex=Male,
#      Age=Adult,
#      Survived=Yes} => {Class=Crew}   0.08723308 0.56804734 1.4127369
# 93  {Class=Crew,
#      Sex=Male,
#      Age=Adult}    => {Survived=Yes} 0.08723308 0.22273782 0.6895161
# 94  {Class=1st}    => {Sex=Male}     0.08178101 0.55384615 0.7042261
# 95  {Sex=Male}     => {Class=1st}    0.08178101 0.10398614 0.7042261
# 96  {Class=2nd}    => {Sex=Male}     0.08132667 0.62807018 0.7986034
# 97  {Sex=Male}     => {Class=2nd}    0.08132667 0.10340843 0.7986034
# 98  {Class=3rd}    => {Survived=Yes} 0.08087233 0.25212465 0.7804871
# 99  {Survived=Yes} => {Class=3rd}    0.08087233 0.25035162 0.7804871
# 100 {Class=1st,
#      Sex=Male}     => {Age=Adult}    0.07950931 0.97222222 1.0228782
# 101 {Class=1st,
#      Age=Adult}    => {Sex=Male}     0.07950931 0.54858934 0.6975420
# 102 {Sex=Male,
#      Age=Adult}    => {Class=1st}    0.07950931 0.10497900 0.7109501
# 103 {Class=2nd,
#      Sex=Male}     => {Age=Adult}    0.07632894 0.93854749 0.9874489
# 104 {Class=2nd,
#      Age=Adult}    => {Sex=Male}     0.07632894 0.64367816 0.8184492
# 105 {Sex=Male,
#      Age=Adult}    => {Class=2nd}    0.07632894 0.10077984 0.7783033
# 106 {Class=2nd}    => {Survived=No}  0.07587460 0.58596491 0.8655764
# 107 {Survived=No}  => {Class=2nd}    0.07587460 0.11208054 0.8655764
# 108 {Class=2nd,
#      Survived=No}  => {Age=Adult}    0.07587460 1.00000000 1.0521033
# 109 {Class=2nd,
#      Age=Adult}    => {Survived=No}  0.07587460 0.63984674 0.9451696
# 110 {Age=Adult,
#      Survived=No}  => {Class=2nd}    0.07587460 0.11613352 0.8968768
# 111 {Class=3rd,
#      Sex=Female}   => {Age=Adult}    0.07496592 0.84183673 0.8856992
# 112 {Sex=Female,
#      Age=Adult}    => {Class=3rd}    0.07496592 0.38823529 1.2103483
# 113 {Class=3rd,
#      Age=Adult}    => {Sex=Female}   0.07496592 0.26315789 1.2323628
# 114 {Class=2nd,
#      Survived=No}  => {Sex=Male}     0.06996820 0.92215569 1.1725388
# 115 {Class=2nd,
#      Sex=Male}     => {Survived=No}  0.06996820 0.86033520 1.2708710
# 116 {Sex=Male,
#      Survived=No}  => {Class=2nd}    0.06996820 0.11290323 0.8719298
# 117 {Class=2nd,
#      Sex=Male,
#      Survived=No}  => {Age=Adult}    0.06996820 1.00000000 1.0521033
# 118 {Class=2nd,
#      Age=Adult,
#      Survived=No}  => {Sex=Male}     0.06996820 0.92215569 1.1725388
# 119 {Class=2nd,
#      Sex=Male,
#      Age=Adult}    => {Survived=No}  0.06996820 0.91666667 1.3540828
# 120 {Sex=Male,
#      Age=Adult,
#      Survived=No}  => {Class=2nd}    0.06996820 0.11587660 0.8948926
# 121 {Class=3rd,
#      Survived=Yes} => {Age=Adult}    0.06860518 0.84831461 0.8925146
# 122 {Class=3rd,
#      Age=Adult}    => {Survived=Yes} 0.06860518 0.24082935 0.7455209
# 123 {Age=Adult,
#      Survived=Yes} => {Class=3rd}    0.06860518 0.23088685 0.7198045
# 124 {Class=1st}    => {Sex=Female}   0.06587915 0.44615385 2.0893290
# 125 {Sex=Female}   => {Class=1st}    0.06587915 0.30851064 2.0893290
# 126 {Class=1st,
#      Sex=Female}   => {Age=Adult}    0.06542481 0.99310345 1.0448474
# 127 {Class=1st,
#      Age=Adult}    => {Sex=Female}   0.06542481 0.45141066 2.1139465
# 128 {Sex=Female,
#      Age=Adult}    => {Class=1st}    0.06542481 0.33882353 2.2946172
# 129 {Class=1st,
#      Sex=Female}   => {Survived=Yes} 0.06406179 0.97241379 3.0102430
# 130 {Class=1st,
#      Survived=Yes} => {Sex=Female}   0.06406179 0.69458128 3.2527094
# 131 {Sex=Female,
#      Survived=Yes} => {Class=1st}    0.06406179 0.40988372 2.7758587
# 132 {Class=1st,
#      Sex=Female,
#      Survived=Yes} => {Age=Adult}    0.06360745 0.99290780 1.0446415
# 133 {Class=1st,
#      Sex=Female,
#      Age=Adult}    => {Survived=Yes} 0.06360745 0.97222222 3.0096499
# 134 {Class=1st,
#      Age=Adult,
#      Survived=Yes} => {Sex=Female}   0.06360745 0.71065990 3.3280052
# 135 {Sex=Female,
#      Age=Adult,
#      Survived=Yes} => {Class=1st}    0.06360745 0.44303797 3.0003895
# 136 {Sex=Female}   => {Survived=No}  0.05724671 0.26808511 0.3960103
# 137 {Survived=No}  => {Sex=Female}   0.05724671 0.08456376 0.3960103
# 138 {Class=1st}    => {Survived=No}  0.05542935 0.37538462 0.5545111
# 139 {Survived=No}  => {Class=1st}    0.05542935 0.08187919 0.5545111
# 140 {Class=1st,
#      Survived=No}  => {Age=Adult}    0.05542935 1.00000000 1.0521033
# 141 {Class=1st,
#      Age=Adult}    => {Survived=No}  0.05542935 0.38244514 0.5649408
# 142 {Age=Adult,
#      Survived=No}  => {Class=1st}    0.05542935 0.08484006 0.5745630
# 143 {Class=2nd}    => {Survived=Yes} 0.05361199 0.41403509 1.2817036
# 144 {Survived=Yes} => {Class=2nd}    0.05361199 0.16596343 1.2817036
# 145 {Class=1st,
#      Survived=No}  => {Sex=Male}     0.05361199 0.96721311 1.2298302
# 146 {Class=1st,
#      Sex=Male}     => {Survived=No}  0.05361199 0.65555556 0.9683743
# 147 {Sex=Male,
#      Survived=No}  => {Class=1st}    0.05361199 0.08651026 0.5858741
# 148 {Class=1st,
#      Sex=Male,
#      Survived=No}  => {Age=Adult}    0.05361199 1.00000000 1.0521033
# 149 {Class=1st,
#      Age=Adult,
#      Survived=No}  => {Sex=Male}     0.05361199 0.96721311 1.2298302
# 150 {Class=1st,
#      Sex=Male,
#      Age=Adult}    => {Survived=No}  0.05361199 0.67428571 0.9960422
# 151 {Sex=Male,
#      Age=Adult,
#      Survived=No}  => {Class=1st}    0.05361199 0.08878856 0.6013035
# 152 {}             => {Age=Child}    0.04952294 0.04952294 1.0000000
# 153 {Sex=Female,
#      Survived=No}  => {Age=Adult}    0.04952294 0.86507937 0.9101528
# 154 {Sex=Female,
#      Age=Adult}    => {Survived=No}  0.04952294 0.25647059 0.3788535
# 155 {Age=Adult,
#      Survived=No}  => {Sex=Female}   0.04952294 0.07579972 0.3549685
# 156 {Class=2nd}    => {Sex=Female}   0.04815993 0.37192982 1.7417395
# 157 {Sex=Female}   => {Class=2nd}    0.04815993 0.22553191 1.7417395
# 158 {Class=3rd,
#      Sex=Female}   => {Survived=No}  0.04815993 0.54081633 0.7988837
# 159 {Sex=Female,
#      Survived=No}  => {Class=3rd}    0.04815993 0.84126984 2.6227124
# 160 {Class=3rd,
#      Survived=No}  => {Sex=Female}   0.04815993 0.20075758 0.9401435
# 161 {Class=2nd,
#      Survived=Yes} => {Age=Adult}    0.04270786 0.79661017 0.8381161
# 162 {Class=2nd,
#      Age=Adult}    => {Survived=Yes} 0.04270786 0.36015326 1.1149048
# 163 {Age=Adult,
#      Survived=Yes} => {Class=2nd}    0.04270786 0.14373089 1.1100059
# 164 {Class=2nd,
#      Sex=Female}   => {Survived=Yes} 0.04225352 0.87735849 2.7159860
# 165 {Class=2nd,
#      Survived=Yes} => {Sex=Female}   0.04225352 0.78813559 3.6908222
# 166 {Sex=Female,
#      Survived=Yes} => {Class=2nd}    0.04225352 0.27034884 2.0878519
# 167 {Class=2nd,
#      Sex=Female}   => {Age=Adult}    0.04225352 0.87735849 0.9230717
# 168 {Class=2nd,
#      Age=Adult}    => {Sex=Female}   0.04225352 0.35632184 1.6686476
# 169 {Sex=Female,
#      Age=Adult}    => {Class=2nd}    0.04225352 0.21882353 1.6899319
# 170 {Class=3rd,
#      Sex=Female}   => {Survived=Yes} 0.04089050 0.45918367 1.4214673
# 171 {Sex=Female,
#      Survived=Yes} => {Class=3rd}    0.04089050 0.26162791 0.8156417
# 172 {Class=3rd,
#      Survived=Yes} => {Sex=Female}   0.04089050 0.50561798 2.3677982
# 173 {Class=3rd,
#      Sex=Female,
#      Survived=No}  => {Age=Adult}    0.04043617 0.83962264 0.8833697
# 174 {Class=3rd,
#      Sex=Female,
#      Age=Adult}    => {Survived=No}  0.04043617 0.53939394 0.7967826
# 175 {Sex=Female,
#      Age=Adult,
#      Survived=No}  => {Class=3rd}    0.04043617 0.81651376 2.5455337
# 176 {Class=3rd,
#      Age=Adult,
#      Survived=No}  => {Sex=Female}   0.04043617 0.18697479 0.8755990
# 177 {Class=3rd,
#      Survived=Yes} => {Sex=Male}     0.03998183 0.49438202 0.6286163
# 178 {Class=3rd,
#      Sex=Male}     => {Survived=Yes} 0.03998183 0.17254902 0.5341496
# 179 {Sex=Male,
#      Survived=Yes} => {Class=3rd}    0.03998183 0.23978202 0.7475357
# 180 {Class=2nd,
#      Sex=Female,
#      Survived=Yes} => {Age=Adult}    0.03634711 0.86021505 0.9050351
# 181 {Class=2nd,
#      Sex=Female,
#      Age=Adult}    => {Survived=Yes} 0.03634711 0.86021505 2.6629161
# 182 {Class=2nd,
#      Age=Adult,
#      Survived=Yes} => {Sex=Female}   0.03634711 0.85106383 3.9855138
# 183 {Sex=Female,
#      Age=Adult,
#      Survived=Yes} => {Class=2nd}    0.03634711 0.25316456 1.9551410
# 184 {Age=Child}    => {Class=3rd}    0.03589278 0.72477064 2.2595187
# 185 {Class=3rd}    => {Age=Child}    0.03589278 0.11189802 2.2595187
# 186 {Class=3rd,
#      Sex=Female,
#      Survived=Yes} => {Age=Adult}    0.03452976 0.84444444 0.8884427
# 187 {Class=3rd,
#      Sex=Female,
#      Age=Adult}    => {Survived=Yes} 0.03452976 0.46060606 1.4258705
# 188 {Sex=Female,
#      Age=Adult,
#      Survived=Yes} => {Class=3rd}    0.03452976 0.24050633 0.7497938
# 189 {Class=3rd,
#      Age=Adult,
#      Survived=Yes} => {Sex=Female}   0.03452976 0.50331126 2.3569959
# 190 {Class=3rd,
#      Sex=Male,
#      Survived=Yes} => {Age=Adult}    0.03407542 0.85227273 0.8966789
# 191 {Class=3rd,
#      Age=Adult,
#      Survived=Yes} => {Sex=Male}     0.03407542 0.49668874 0.6315493
# 192 {Class=3rd,
#      Sex=Male,
#      Age=Adult}    => {Survived=Yes} 0.03407542 0.16233766 0.5025390
# 193 {Sex=Male,
#      Age=Adult,
#      Survived=Yes} => {Class=3rd}    0.03407542 0.22189349 0.6917671
# 194 {Age=Child}    => {Sex=Male}     0.02907769 0.58715596 0.7465802
# 195 {Sex=Male}     => {Age=Child}    0.02907769 0.03697285 0.7465802
# 196 {Class=1st,
#      Survived=Yes} => {Sex=Male}     0.02816901 0.30541872 0.3883458
# 197 {Class=1st,
#      Sex=Male}     => {Survived=Yes} 0.02816901 0.34444444 1.0662760
# 198 {Sex=Male,
#      Survived=Yes} => {Class=1st}    0.02816901 0.16893733 1.1440956
# 199 {Age=Child}    => {Survived=Yes} 0.02589732 0.52293578 1.6188209
# 200 {Survived=Yes} => {Age=Child}    0.02589732 0.08016878 1.6188209
# 201 {Class=1st,
#      Sex=Male,
#      Survived=Yes} => {Age=Adult}    0.02589732 0.91935484 0.9672562
# 202 {Class=1st,
#      Age=Adult,
#      Survived=Yes} => {Sex=Male}     0.02589732 0.28934010 0.3679015
# 203 {Class=1st,
#      Sex=Male,
#      Age=Adult}    => {Survived=Yes} 0.02589732 0.32571429 1.0082942
# 204 {Sex=Male,
#      Age=Adult,
#      Survived=Yes} => {Class=1st}    0.02589732 0.16863905 1.1420756
# 205 {Age=Child}    => {Survived=No}  0.02362562 0.47706422 0.7047103
# 206 {Survived=No}  => {Age=Child}    0.02362562 0.03489933 0.7047103
# 207 {Class=3rd,
#      Age=Child}    => {Survived=No}  0.02362562 0.65822785 0.9723218
# 208 {Age=Child,
#      Survived=No}  => {Class=3rd}    0.02362562 1.00000000 3.1175637
# 209 {Class=3rd,
#      Survived=No}  => {Age=Child}    0.02362562 0.09848485 1.9886711
# 210 {Class=3rd,
#      Age=Child}    => {Sex=Male}     0.02180827 0.60759494 0.7725687
# 211 {Sex=Male,
#      Age=Child}    => {Class=3rd}    0.02180827 0.75000000 2.3381728
# 212 {Class=3rd,
#      Sex=Male}     => {Age=Child}    0.02180827 0.09411765 1.9004857
# 213 {Age=Child}    => {Sex=Female}   0.02044525 0.41284404 1.9333398
# 214 {Sex=Female}   => {Age=Child}    0.02044525 0.09574468 1.9333398
# 215 {Age=Child,
#      Survived=No}  => {Sex=Male}     0.01590186 0.67307692 0.8558303
# 216 {Sex=Male,
#      Age=Child}    => {Survived=No}  0.01590186 0.54687500 0.8078335
# 217 {Sex=Male,
#      Survived=No}  => {Age=Child}    0.01590186 0.02565982 0.5181401
# 218 {Class=3rd,
#      Age=Child,
#      Survived=No}  => {Sex=Male}     0.01590186 0.67307692 0.8558303
# 219 {Class=3rd,
#      Sex=Male,
#      Age=Child}    => {Survived=No}  0.01590186 0.72916667 1.0771113
# 220 {Sex=Male,
#      Age=Child,
#      Survived=No}  => {Class=3rd}    0.01590186 1.00000000 3.1175637
# 221 {Class=3rd,
#      Sex=Male,
#      Survived=No}  => {Age=Child}    0.01590186 0.08293839 1.6747467
# 222 {Sex=Female,
#      Age=Child}    => {Class=3rd}    0.01408451 0.68888889 2.1476550
# 223 {Class=3rd,
#      Age=Child}    => {Sex=Female}   0.01408451 0.39240506 1.8376246
# 224 {Class=3rd,
#      Sex=Female}   => {Age=Child}    0.01408451 0.15816327 3.1937371
# 225 {Age=Child,
#      Survived=Yes} => {Sex=Male}     0.01317583 0.50877193 0.6469134
# 226 {Sex=Male,
#      Age=Child}    => {Survived=Yes} 0.01317583 0.45312500 1.4027118
# 227 {Sex=Male,
#      Survived=Yes} => {Age=Child}    0.01317583 0.07901907 1.5956053
# 228 {Sex=Female,
#      Age=Child}    => {Survived=Yes} 0.01272149 0.62222222 1.9261760
# 229 {Age=Child,
#      Survived=Yes} => {Sex=Female}   0.01272149 0.49122807 2.3004106
# 230 {Sex=Female,
#      Survived=Yes} => {Age=Child}    0.01272149 0.08139535 1.6435886
# 231 {Class=3rd,
#      Age=Child}    => {Survived=Yes} 0.01226715 0.34177215 1.0580035
# 232 {Age=Child,
#      Survived=Yes} => {Class=3rd}    0.01226715 0.47368421 1.4767407
# 233 {Class=3rd,
#      Survived=Yes} => {Age=Child}    0.01226715 0.15168539 3.0629317
# 234 {Class=2nd,
#      Survived=Yes} => {Sex=Male}     0.01135847 0.21186441 0.2693897
# 235 {Class=2nd,
#      Sex=Male}     => {Survived=Yes} 0.01135847 0.13966480 0.4323519
# 236 {Sex=Male,
#      Survived=Yes} => {Class=2nd}    0.01135847 0.06811989 0.5260768
# 237 {Age=Child}    => {Class=2nd}    0.01090413 0.22018349 1.7004346
# 238 {Class=2nd}    => {Age=Child}    0.01090413 0.08421053 1.7004346
# 239 {Class=2nd,
#      Age=Child}    => {Survived=Yes} 0.01090413 1.00000000 3.0956399
# 240 {Age=Child,
#      Survived=Yes} => {Class=2nd}    0.01090413 0.42105263 3.2517082
# 241 {Class=2nd,
#      Survived=Yes} => {Age=Child}    0.01090413 0.20338983 4.1069818
# 242 {Sex=Female}   => {Class=Crew}   0.01044980 0.04893617 0.1217045
# 243 {Class=Crew}   => {Sex=Female}   0.01044980 0.02598870 0.1217045
# 244 {Class=Crew,
#      Sex=Female}   => {Age=Adult}    0.01044980 1.00000000 1.0521033
# 245 {Sex=Female,
#      Age=Adult}    => {Class=Crew}   0.01044980 0.05411765 0.1345909
# 246 {Class=Crew,
#      Age=Adult}    => {Sex=Female}   0.01044980 0.02598870 0.1217045

# %%
#========================================================================================================
# IF NOT USING R RUN THIS CODE (It is an example snapshot of using arules) AND INTERPRET THE OUTPUTS
#========================================================================================================
from IPython.display import Image
Image('R_arules_output.png')

#========================================================================================================
# Also, change the parameters to the following line of code to what you think they should be to answer the question:
#========================================================================================================

# rules <- apriori(titanic.raw, parameter = list(minlen=4, supp=0.01, conf=0.01))

# %% [markdown]
# ___
# Enter your answer here:
#
# They do match with the answers in the previous question, though they do not need to because we assumed everything not in the 3-itemset graph was infrequent.
#
#
# ___

# %% [markdown]
# ## Using the Arules Viz Package
# Now run the following code to visualize the rules from the previous step. There are various parameters built into the visualization such as support, confidence, and a parameter known as "lift." Lift is a measure that ranks different rules using the equation
# $$ Lift = \frac{P(Y|X)}{P(Y)} = \frac{c(X\rightarrow Y)}{s(Y)} $$
# In practice, there are many different measures that we use to rank the rules from a dataset, but, at the end of the day, a human evaluates which rules are most subjectively interesting. The arulesViz library allows many different types of interpretations for looking at lift and confidence together. The documentation is here:
# http://cran.r-project.org/web/packages/arulesViz/arulesViz.pdf
#
# The styles of plot are "scatterplot", "two-key plot", "matrix", "matrix3D", "graph", "paracoord" or "grouped." Each provides a different view of the rules. Try at least three plots using the boilerplate code below (you just need to change the "method" parameter of the plot). After looking at the visualizations answer the following:
#
# **Question**: Which rules are the most interesting according to Lift, according to confidence, and, lastly, according to you? Why?

# %%
#=========================================
# IF USING R, RUN THIS CODE
#=========================================
# do not change the arules code
# %R rules <- apriori(titanic.raw,parameter = list(minlen=2, supp=0.05, conf=0.8), appearance = list(rhs=c("Survived=No", "Survived=Yes"), default="lhs"), control = list(verbose=F))
# %R rules.sorted <- sort(rules, by="lift")

# change or add plots using the following lines:
# %R plot(rules.sorted, method="grouped", measure = 'confidence', shading='lift')

print('The Graphic for rules grouped by lift and their support')
# Out:
# The Graphic for rules grouped by lift and their support

# %%
#======================================================================
#IF NOT USING R RUN THIS BLOCK AND THE BLOCK AFTERWARD TO SEE EXAMPLES 
#======================================================================
from IPython.display import Image
Image('Arules_grouped.png')

# %%
Image('Arules_graph2_3.png')

# %% [markdown]
# ___
# Enter your answer here:
#
# According to lift, the most interesting rule is: 1st class female -> survived
#
# According to confidence, the most intersting rule is: 1st class female -> survived
#
# According to us (humans), the most intersting rule is: being in first class lead to a high survivability
#
#
# ___

# %% [markdown]
# **Question**: Who is the lead author (and maintainer) for the arules package and the arulesViz package? What University does he/she currently teach at?
#
# http://cran.r-project.org/web/packages/arules/arules.pdf
#
# http://cran.r-project.org/web/packages/arulesViz/arulesViz.pdf

# %% [markdown]
# ___
# Enter your answer here:
#
# Dr. Michael Hahsler is the lead author for the arules package and the arulesViz package. He currently teaches at Southern Methodist University (SMU).
#
#
# ___

# %% [markdown]
# ________________________________________________________________________________________________________
#
# That's all! Please **upload your rendered notebook** and please include **team member names** in the notebook submission.
